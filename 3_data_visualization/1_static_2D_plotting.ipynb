# %% [markdown]
# # Static 2D plotting

# %% [markdown]
# ## One-Dimensional Data Sets

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
mpl.__version__
# Out:
# '3.7.0'

# %%
sns.set(style="whitegrid") 
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
# x,y shows the lists of arrays containing the values of the abscissa and ordinate respectively
np.random.seed(1000)

# %%
y = np.random.standard_normal(20)

# %% [markdown]
# ### Plot the given x and y values

# %%
x = np.arange(len(y))
plt.plot(x, y)

# %% [markdown]
# ### Plot given data as an ndarray object

# %%
plt.plot(y)
# if we only provide the y values, plt.plot() takes the index values at the respective x values.

# %% [markdown]
# ### Cumulative Sum

# %%
plt.plot(y.cumsum())

# %% [markdown]
# ### Plot without grid
# Different plotting styles may be required for different publications and different requirements

# %%
plt.plot(y.cumsum())
plt.grid(False)
plt.axis('equal')
# Out:
# (-0.9500000000000001, 19.95, -2.322818663749045, 0.5655085808655865)

# %% [markdown]
# ### Plot with Custom Axis Limits

# %%
plt.plot(y.cumsum())
plt.xlim(-1, 20)
plt.ylim(np.min(y.cumsum()) -1,
         np.max(y.cumsum()) +1)
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %% [markdown]
# ### Plot with Typical Labels

# %%
plt.figure(figsize=(10, 6))
plt.plot(y.cumsum(), 'b', lw = 1.5)
plt.plot(y.cumsum(), 'ro')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('A simple plot with typical labels')
# Out:
# Text(0.5, 1.0, 'A simple plot with typical labels')

# %% [markdown]
# ## Two Dimensional Datasets

# %% [markdown]
# ### Plot with two datasets

# %%
# generates a two-dimensional sample data set as NumPy ndarray object of shape 20 X 2 with standard normally distributed pseudo-random numbers.
y = np.random.standard_normal((20, 2)).cumsum(axis=0)

# %%
plt.figure(figsize=(10, 6))
plt.plot(y, lw =1.5)
plt.plot(y, 'ro')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title(' A Plot with two datasets')
# Out:
# Text(0.5, 1.0, ' A Plot with two datasets')

# %% [markdown]
# ### Plot with labeled data sets

# %%
plt.figure(figsize=(10, 6))
plt.plot(y[:, 0], lw = 1.5, label = '1st')
plt.plot(y[:, 1], lw = 1.5, label = '2nd')
plt.plot(y, 'ro')
plt.legend(loc = 0)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title(' A simple plot with labeled data sets')
# Out:
# Text(0.5, 1.0, ' A simple plot with labeled data sets')

# %% [markdown]
# ### Plot with two differently scaled datasets

# %%
# it scales the first two data subsets by a factor of 100 and plots the data again
y [:, 0] = y[:, 0 ] * 100

# %%
plt.figure(figsize=(10, 6))
plt.plot(y[:, 0], lw = 1.5, label = '1st')
plt.plot(y[:, 1], lw = 1.5, label = '2nd')
plt.plot(y, 'ro')
plt.legend(loc = 0)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title(' A simple plot with two differently scaled data sets')
# Out:
# Text(0.5, 1.0, ' A simple plot with two differently scaled data sets')

# %% [markdown]
# From the inspection of the above plot, we can see that the first data is still "visually readable", while the second data set looks like a straight line with the new scaling

# %% [markdown]
# ### Plot with two data sets and two y - axis

# %%
fig, ax1 = plt.subplots()
plt.plot(y[:, 0], 'b', lw = 1.5, label = '1st')
plt.plot(y[:, 0], 'ro')
plt.legend(loc = 8)
plt.xlabel('Index')
plt.ylabel('Value 1st')
plt.title('A Simple Plot with two data sets and two y-axis')
ax2 = ax1.twinx()
plt.plot(y[:, 1], 'g', lw = 1.5, label = '2nd')
plt.plot(y[:, 1], 'ro')
plt.legend(loc = 0)
plt.ylabel("Value 2nd")
# Out:
# Text(0, 0.5, 'Value 2nd')

# %% [markdown]
# ## Plot with two sub plots

# %%
plt.figure(figsize=(10, 6))
plt.subplot(211)
plt.plot(y[:, 0], lw = 1.5, label = '1st')
plt.plot(y[:, 0], 'ro')
plt.legend(loc = 0 )
plt.ylabel('Value')
plt.title('Plot with two sub plots')
plt.subplot(212)
plt.plot(y[:, 1], lw = 1.5, label = '2nd')
plt.plot(y[:, 1], 'ro')
plt.legend(loc = 0)
plt.xlabel('Index')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# ### Plot combining the line/point subplot with bar subplot

# %%
plt.figure(figsize=(10, 6))
plt.subplot(121)
plt.plot(y[:, 0], lw = 1.5, label = '1st')
plt.plot(y[:, 0], 'ro')
plt.legend(loc = 0 )
plt.ylabel('Index')
plt.ylabel('Value')
plt.title('1st Data Set')
plt.subplot(122)
plt.bar(np.arange(len(y)), y[:, 1], width = 0.5, color = 'g', label = '2nd')
plt.legend(loc = 0)
plt.xlabel('Index')
plt.ylabel('2nd dataset')
# Out:
# Text(0, 0.5, '2nd dataset')

# %% [markdown]
# ### Scatter plot with the plt.plot() function

# %%
y = np.random.standard_normal((1000, 2))

# %%
plt.figure(figsize = (10, 6))
plt.plot(y[:, 0], y[:, 1], 'ro')
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %% [markdown]
# ### Scatter Plot with the plt.scatter() function

# %%
plt.figure(figsize= (10, 6))
plt.scatter(y[:, 0], y[:, 1], marker='o')
plt.xlabel('1st')
plt.ylabel('2nd')
# Out:
# Text(0, 0.5, '2nd')

# %% [markdown]
# ### Scatter Plot with 3rd dimension

# %%
c = np.random.randint(0, 10, len(y))

# %%
plt.figure(figsize = (10, 6))
plt.scatter(y[:, 0], y[:, 1], c = c, cmap='coolwarm', marker='o')
plt.colorbar()
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter plot with 3rd Dimension')
# Out:
# Text(0.5, 1.0, 'Scatter plot with 3rd Dimension')
